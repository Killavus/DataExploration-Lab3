# %%
import numpy as np
from numpy.random import multinomial, normal

# TrivialCovariances = All Covariances are Eye Matrices, it simplifies the process a lot
def SamplesFromGaussianMixture(Probs, Means, CovarianceMatrices, SampleCount, TrivialCovariances=False):
  MixtureCount = Probs.shape[0]  
  Dimension    = Means.shape[1]
  CholeskyMatrices = CovarianceMatrices
  if not TrivialCovariances:
      CholeskyMatrices = np.linalg.cholesky(CovarianceMatrices) # K x d x d
    
  ResultSet = np.empty(shape=(Dimension, SampleCount)) # d x N
  Choices = np.zeros(SampleCount)

  MixturesToSample = multinomial(SampleCount, Probs)
  GeneratedSamples = 0
  for MixtureInd in range(MixtureCount):
     Count = MixturesToSample[MixtureInd]
     ZMatrix = normal(size=(Dimension, Count))
     if not TrivialCovariances:
       ZMatrix = np.dot(CholeskyMatrices[MixtureInd], ZMatrix)
     ResultSet[:, GeneratedSamples:(GeneratedSamples + Count)] = ZMatrix + Means[MixtureInd].reshape(Means[MixtureInd].shape[0], 1)
     Choices[GeneratedSamples:(GeneratedSamples + Count)] = MixtureInd
     GeneratedSamples += Count
 
  return ResultSet, Choices

# %%
import numpy as np
from numpy.random import randint
from scipy.sparse import csr_matrix

# (d x N) -> K -> ?(d x K) -> (N x K)
def HardCMeans(DataSet, ClusterCount, InitialCenters = None, Precision = np.float_):
   DataSetSize        = DataSet.shape[1]
   Dimension          = DataSet.shape[0]

   # Init:
   OldClusterCenterMx = None
   ClusterCenterMx    = None
   
   OldClusterAssignMx = None
   ClusterAssignMx    = None

   # We can provide initial centers:
   if InitialCenters is None:
      print 'Initial Centers Randomized'
      InitialCenterIndices = randint(0, DataSetSize, ClusterCount)
      ClusterCenterMx      = np.array(DataSet[:,InitialCenterIndices], copy=True)
   else:
      print 'Initial Centers Provided'
      ClusterCenterMx = np.array(InitialCenters, copy=True)    

   RowIndices     = np.arange(0, DataSetSize)
   DSizeRankOnes  = np.ones(DataSetSize)
   DistanceMatrix = np.empty(shape=(DataSet.shape[1], ClusterCount), dtype=Precision)

   while (((OldClusterAssignMx is None) or ((OldClusterAssignMx != ClusterAssignMx).nnz != 0)) and 
      ((OldClusterCenterMx is None) or not np.array_equal(OldClusterCenterMx, ClusterCenterMx))):
      OldClusterAssignMx = ClusterAssignMx
      OldClusterCenterMx = ClusterCenterMx
        
      # Computing Distance Matrix:
      np.dot(DataSet.T, ClusterCenterMx, out=DistanceMatrix)
      DistanceMatrix *= -2
      DistanceMatrix += np.sum(ClusterCenterMx ** 2, axis=0, keepdims=True)
    
      # Computing Closest Center:
      BestAssignments = np.argmin(DistanceMatrix, axis=1)

      # Computing Assignment Matrix
      ClusterAssignMx = csr_matrix((DSizeRankOnes, (RowIndices, BestAssignments)), shape=(DataSetSize, ClusterCount))
    
      # Computing New Centers:
      ClusterCenterMx = ClusterAssignMx.T.dot(DataSet.T).T
      ClusterCenterMx /= ClusterAssignMx.sum(axis=0)
    
   return ClusterAssignMx.toarray(), ClusterCenterMx

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (18.0, 12.0)

Dimension     = 2
SampleCount   = 5000
MixtureCount  = 5
Propabilities = np.ones(MixtureCount) / MixtureCount
MeanMatrix    = np.ones((MixtureCount, Dimension))
MeanSteps     = np.arange(0, 3 * MixtureCount, 3)
Means         = MeanMatrix * MeanSteps.reshape(MeanSteps.shape[0], 1)
CovarianceMxs = np.full((MixtureCount, Dimension, Dimension), np.eye(Dimension))

Samples, Groups = SamplesFromGaussianMixture(Propabilities, Means, CovarianceMxs, SampleCount)

def PerformTest(MixtureCount, SampleCount, Dimension, Groups, Samples):
    # Sensible Centres
    InitialCentres = np.empty(shape=(Dimension, MixtureCount))
    for Group in range(MixtureCount):
        GroupMask = Group == Groups
        GroupSize = np.sum(GroupMask)
    
        SummedDims = np.sum(Samples[:, GroupMask], axis=1)
        InitialCentres[:, Group] = SummedDims / GroupSize

    Assignments, UnusedFinalCentres = HardCMeans(Samples, MixtureCount, InitialCentres)
    AssignmentsForm = np.nonzero(Assignments)[1]
    # Error Computation:
    for Group in range(MixtureCount):
        GroupMask = Group == Groups
        GroupSize = np.sum(GroupMask)
        
        AssignmentsMask = Group == AssignmentsForm

        Error = (np.sum(GroupMask != AssignmentsMask) / float(GroupSize)) * 100.0
        print "Group #%d err percentage: %1.8f" % (Group + 1, Error)
    
    OverallError = (np.sum(Groups != AssignmentsForm) / float(SampleCount)) * 100.0
    print "Overall  err percentage: %1.8f" % (OverallError)
    
    # if dim = 2 - plotting:
    if Dimension == 2:
        subplot(2, 1, 1)        
        title("Real Group Assignments")
        subplot(2, 1, 2)
        title("K-Means Group Assignments")
        
        Colors = 'rgbcm'
        for Group in range(MixtureCount):
            subplot(2, 1, 1)        
            GroupMask = Group == Groups
            scatter(Samples[0, GroupMask], Samples[1, GroupMask], 
                    color=Colors[Group], 
                    label="Group %d" % (Group+1), 
                    alpha=.75)
            
            AssignmentsMask = Group == AssignmentsForm
            subplot(2, 1, 2)
            scatter(Samples[0, AssignmentsMask], Samples[1, AssignmentsMask],
                    color=Colors[Group],
                    label="Group %d" % (Group+1),
                    alpha=.75)
            
        subplot(2, 1, 1)
        legend(loc='best')
        subplot(2, 1, 2)
        legend(loc='best')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
PerformTest(MixtureCount, SampleCount, Dimension, Groups, Samples)
# Out:
# Initial Centers Provided
# Group #1 err percentage: 3.38809035
# Group #2 err percentage: 6.30630631
# Group #3 err percentage: 7.02306080
# Group #4 err percentage: 7.26368159
# Group #5 err percentage: 3.37078652
# Overall  err percentage: 2.72000000

# %%
CovarianceMxs[2] = np.array([[3, 0], [0, 1]])
Samples, Groups = SamplesFromGaussianMixture(Propabilities, Means, CovarianceMxs, SampleCount)
PerformTest(MixtureCount, SampleCount, Dimension, Groups, Samples)
# Out:
# Initial Centers Provided
# Group #1 err percentage: 2.92044310
# Group #2 err percentage: 10.14492754
# Group #3 err percentage: 18.83052527
# Group #4 err percentage: 15.36174430
# Group #5 err percentage: 3.32355816
# Overall  err percentage: 5.06000000

# %%
CovarianceMxs[0] = np.array([[3, 1], [1, 1]])
Samples, Groups = SamplesFromGaussianMixture(Propabilities, Means, CovarianceMxs, SampleCount)
PerformTest(MixtureCount, SampleCount, Dimension, Groups, Samples)
# Out:
# Initial Centers Provided
# Group #1 err percentage: 17.52988048
# Group #2 err percentage: 24.89919355
# Group #3 err percentage: 15.82661290
# Group #4 err percentage: 12.84125379
# Group #5 err percentage: 4.00782014
# Overall  err percentage: 7.48000000

# %%
Propabilities = np.array([0.2, 0.1, 0.3, 0.1, 0.3])
Samples, Groups = SamplesFromGaussianMixture(Propabilities, Means, CovarianceMxs, SampleCount)
PerformTest(MixtureCount, SampleCount, Dimension, Groups, Samples)
# Out:
# Loaded initial centres
# Group #1 err percentage: 2.04962244
# Group #2 err percentage: 33.26810176
# Group #3 err percentage: 18.22950820
# Group #4 err percentage: 33.47107438
# Group #5 err percentage: 2.25370251
# Overall  err percentage: 6.64000000

# %%
Dimension = 3
Propabilities = np.ones(MixtureCount) / MixtureCount
MeanMatrix    = np.ones((MixtureCount, Dimension))
MeanSteps     = np.arange(0, 3 * MixtureCount, 3)
Means         = MeanMatrix * MeanSteps.reshape(MeanSteps.shape[0], 1)
CovarianceMxs = np.full((MixtureCount, Dimension, Dimension), np.eye(Dimension))

Samples, Groups = SamplesFromGaussianMixture(Propabilities, Means, CovarianceMxs, SampleCount)
PerformTest(MixtureCount, SampleCount, Dimension, Groups, Samples)
# Out:
# Initial Centers Provided
# Group #1 err percentage: 1.51821862
# Group #2 err percentage: 2.52016129
# Group #3 err percentage: 1.55440415
# Group #4 err percentage: 1.57480315
# Group #5 err percentage: 1.05871030
# Overall  err percentage: 0.82000000

# %%
Dimension     = 100
MixtureCount  = 10
Propabilities = np.ones(MixtureCount) / MixtureCount
MeanMatrix    = np.ones((MixtureCount, Dimension))
MeanSteps     = np.arange(0, 3 * MixtureCount, 3)
Means         = MeanMatrix * MeanSteps.reshape(MeanSteps.shape[0], 1)
CovarianceMxs = np.full((MixtureCount, Dimension, Dimension), np.eye(Dimension))

Samples, Groups = SamplesFromGaussianMixture(Propabilities, Means, CovarianceMxs, SampleCount, False)
PerformTest(MixtureCount, SampleCount, Dimension, Groups, Samples)
# Out:
# Initial Centers Provided
# Group #1 err percentage: 0.00000000
# Group #2 err percentage: 0.00000000
# Group #3 err percentage: 0.00000000
# Group #4 err percentage: 0.00000000
# Group #5 err percentage: 0.00000000
# Group #6 err percentage: 0.00000000
# Group #7 err percentage: 0.00000000
# Group #8 err percentage: 0.00000000
# Group #9 err percentage: 0.00000000
# Group #10 err percentage: 0.00000000
# Overall  err percentage: 0.00000000
